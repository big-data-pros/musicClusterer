# %%
import pandas as pd
import os
from dotenv import load_dotenv

df= pd.read_csv('../data/cleaned_discogs_sample.csv')
# Read only the first 500 rows
df.head()
#! rm status, notes, label_id, format, style, master_id, company_name, release_id, artist_id, 
#* fix video_url-> spotify_url, release_date(get nulls and zeros from spotify api), if(title, doesn't exist, get the first option from spotify api),
#* add popularity, image_url
#TODO: fill genre, label_name, country, release_date, popularity, spotify_url,image_url
print(df.shape)

df
# Out:
# (61, 10)
#                                                    id  \
# 0                                 Produced by Beatnik
# 1                                                  12
# 2                                                  48
# 3   These madrigals were Frescobaldi's first publi...
# 4                                                  10
# ..                                                ...
# 56                            Recorded on December 16
# 57                                                 52
# 58                                                 17
# 59                                                  7
# 60                                                 26
#
#                                                 title  \
# 0                                                 NaN
# 1     Special Album Spot Commercial - Hooker And Heat
# 2      Special Album Spot Commercial - Live In Europe
# 3    the noted English composer of madrigals who h...
# 4                         A Tribute to La Monte Young
# ..                                                ...
# 56        https://www.youtube.com/watch?v=Wwf9NnOQ03k
# 57                                       Εδώ Είμ' Εγώ
# 58                                      Καλημέρα Ήλιε
# 59                                     Κόκκινη Γραμμή
# 60                      Это - Жириновский. Песни 2004
#
#                                           artist_name  \
# 0                                                 NaN
# 1                                         Canned Heat
# 2                                         Canned Heat
# 3    and a transparent counterpoint that favours d...
# 4                                      Infinite Music
# ..                                                ...
# 56                                                NaN
# 57                               Γιώργος Μουφλουζέλης
# 58                                       Μάνος Λοΐζος
# 59                                  Βασίλης Τερλέγκας
# 60                               Владимир Жириновский
#
#                                            label_name                   genre  \
# 0                                                 NaN                     NaN
# 1                                             Liberty                   Blues
# 2                                             Liberty                   Blues
# 3    homophonic and polyphonic sections being clev...                     NaN
# 4                                        Fire Records              Electronic
# ..                                                ...                     ...
# 56                                                NaN                     NaN
# 57                                               Lyra  Folk, World, & Country
# 58                                          Minos (2)  Folk, World, & Country
# 59                                  Alpha Records (6)  Folk, World, & Country
# 60                                            ЦА ЛДПР                     Pop
#
#    country  release_date  popularity  spotify_url  image_url
# 0      NaN           NaN         NaN          NaN        NaN
# 1       US        1971.0         NaN          NaN        NaN
# 2       US        1971.0         NaN          NaN        NaN
# 3      NaN           NaN         NaN          NaN        NaN
# 4       UK        2018.0         NaN          NaN        NaN
# ..     ...           ...         ...          ...        ...
# 56     NaN           NaN         NaN          NaN        NaN
# 57  Greece        1998.0         NaN          NaN        NaN
# 58  Greece           NaN         NaN          NaN        NaN
# 59  Greece           NaN         NaN          NaN        NaN
# 60  Russia        2004.0         NaN          NaN        NaN
#
# [61 rows x 10 columns]

# %%
 
print(df.isnull().sum())
# Out:
# id               0
# title            1
# artist_name      8
# label_name       8
# genre            9
# country         11
# release_date    16
# popularity      61
# spotify_url     61
# image_url       61
# dtype: int64
