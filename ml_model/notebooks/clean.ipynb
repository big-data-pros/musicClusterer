# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import lit
from pyspark.sql.types import StringType
import os
from dotenv import load_dotenv

# Load environment variables from root .env file
load_dotenv(os.path.join(os.path.dirname(os.path.dirname(os.path.dirname('discogs.csv'))), '.env'))

# Set Hadoop home directory
os.environ['HADOOP_HOME'] = 'C:\\hadoop'
os.environ['PATH'] = os.environ['PATH'] + ';C:\\hadoop\\bin'

# Initialize Spark session with current configuration
spark = SparkSession.builder \
    .appName("CSV Cleaner") \
    .config("spark.sql.parquet.datetimeRebaseModeInWrite", "LEGACY") \
    .config("spark.hadoop.fs.defaultFS", "file:///") \
    .config("spark.hadoop.fs.file.impl", "org.apache.hadoop.fs.LocalFileSystem") \
    .getOrCreate()

# Get the local path from environment variable
local_path = os.getenv('LOCAL_PATH')
if not local_path:
    raise ValueError("LOCAL_PATH environment variable not found. Please check your .env file.")

# Construct the full path to the CSV file
csv_path = os.path.join(local_path, 'discogs.csv')

# Read the CSV file
df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv(csv_path) \
    .limit(100)  # For testing, remove this in production

# %%
# Drop unnecessary columns
df = df.drop('status', 'notes', 'label_id', 'format', 'style', 
             'master_id', 'company_name', 'release_id', 'artist_id', 'video_url')
df = df.withColumn('popularity', lit(None).cast(StringType())) \
       .withColumn('spotify_url', lit(None).cast(StringType())) \
       .withColumn('image_url', lit(None).cast(StringType()))

# Show the cleaned data
print("Cleaned Schema:")
df.printSchema()

print("\nFirst 5 rows of cleaned data:")
df.show(5, truncate=False)

print("\nTotal rows:", df.count())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Drop unnecessary columns
# ----> 2 df = df.drop('status', 'notes', 'label_id', 'format', 'style',
#       3              'master_id', 'company_name', 'release_id', 'artist_id', 'video_url')
#       4 df = df.withColumn('popularity', lit(None).cast(StringType())) \
#       5        .withColumn('spotify_url', lit(None).cast(StringType())) \
#       6        .withColumn('image_url', lit(None).cast(StringType()))
#       8 # Show the cleaned data
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
# Convert to Pandas DataFrame for easier manipulation
pandas_df = df.toPandas()
# Save to CSV using Pandas
pandas_df.to_csv( 'D:/flutter_projects/musicClusterer/ml_model/data/cleaned_discogs_sample.csv', index=False)
pandas_df
# # Write to CSV using absolute path
# output_path = os.path.join(local_path, 'cleaned_discogs.csv')
# df.write \
#     .mode("overwrite") \
#     .option("header", "true") \
#     .csv(output_path)
# Out:
#        id release_id                      status  \
# 0       1   12295801                    Accepted
# 1       2   12295802                    Accepted
# 2       3   12295803                    Accepted
# 3       4   12295805                    Accepted
# 4       5   12295806                    Accepted
# ..    ...        ...                         ...
# 95     50   12295857                    Accepted
# 96     51   12295858                    Accepted
# 97  April      2016"                        None
# 98     52   12295859                    Accepted
# 99     ,"       None  General Publishing Company
#
#                                  title artist_id           artist_name  \
# 0               The World Of Ray Price    311678             Ray Price
# 1             The Burden of Isolation    3720243             Filth (9)
# 2                    Bassoon Concertos   6095671   Sebastian Fagerlund
# 3   Ich Lag In Einer Nacht Und Schlief   3170804  Hans Peter Treichler
# 4                           Bien O Mal     85181       Julieta Venegas
# ..                                 ...       ...                   ...
# 95                  Santo De Pau Feito   4263371          Leonel Nunes
# 96                            Wandelen   2163745             De Tuinen
# 97                                None      None                  None
# 98                        Εδώ Είμ' Εγώ   1945520  Γιώργος Μουφλουζέλης
# 99                                None      None                  None
#
#                                 label_name label_id             format  \
# 0                                 Columbia     1866  8-Track Cartridge
# 1   Not on Label (Filth (9) Self-Released)  1495843                 CD
# 2                                      BIS    51038               SACD
# 3                             Gold Records    11489              Vinyl
# 4                               Sony Music    25487                 CD
# ..                                     ...      ...                ...
# 95                               Discotoni   598183           Cassette
# 96                         Beer On The Rug   242586               File
# 97                                    None     None               None
# 98                                    Lyra    73677                 CD
# 99                                    None     None               None
#
#                      genre         style      country release_date  \
# 0   Folk, World, & Country          None           US         1970
# 1                     Rock     Deathcore           US         2018
# 2                Classical  Contemporary       Sweden         2016
# 3                      Pop          None  Switzerland         1980
# 4                    Latin          None    Argentina         2010
# ..                     ...           ...          ...          ...
# 95  Folk, World, & Country          None     Portugal         2006
# 96              Electronic      Abstract           US         2016
# 97                    None          None         None         None
# 98  Folk, World, & Country      Éntekhno       Greece         1998
# 99                    None          None         None         None
#
#                                  notes master_id  \
# 0                                 None      None
# 1                                 None   1397110
# 2                       Made in the EU      None
# 3                                 None      None
# 4                                 None   1418114
# ..                                 ...       ...
# 95                                None      None
# 96  ‘Wandelen’ was recorded in a room.      None
# 97                                None      None
# 98           """Καινούργια Τραγούδια""      None
# 99                                None      None
#
#                                       video_url    company_name
# 0                                          None            None
# 1   https://www.youtube.com/watch?v=mRN-e_mIfQQ            None
# 2                                          None  BIS Records AB
# 3                                          None    Gold Records
# 4   https://www.youtube.com/watch?v=KTr9HMnAWNE    Lolein Music
# ..                                          ...             ...
# 95                                         None            None
# 96                                         None            None
# 97                                         None            None
# 98                                         None            None
# 99                                         None            None
#
# [100 rows x 17 columns]

# %%
# Stop Spark session
spark.stop()
